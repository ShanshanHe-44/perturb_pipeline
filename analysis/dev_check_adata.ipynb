# %%
import pandas as pd
import sys
import scanpy as sc
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
adata = sc.read_h5ad("/scratch/users/shshanhe/eRZ58_40B_analysis/eRZ58:eRZ58_GEX40B/kb_all_main_raw/counts_unfiltered/adata.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 566026 × 34183
#     layers: 'ambiguous', 'mature', 'nascent'

# %%
RESULT_PATH = "/oak/stanford/groups/engreitz/Users/shshanhe/project/perturb_pipeline/analysis/dev_cell_calling_eRZ58:eRZ58_GEX20A_unfilered/"
ADATA_PATH = RESULT_PATH+"/eRZ58:eRZ58_GEX20A.cellcalling.h5ad"
adata = sc.read_h5ad(ADATA_PATH)
obs = adata.obs.copy()
obs
obs.to_csv(RESULT_PATH+"cell_calling_summary_h5ad.csv", index=False)
# Out:
#                           guides_per_cell  guide_umi_counts  pct_counts_ribo  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                5             203.0         0.440613
# AAACATCGAACGCTTAACATTTGG                3             161.0         2.182540
# AAACATCGAACGTGATACTTCATC                3              90.0         0.000000
# AAACATCGAACGTGATCATTTGGA                1              11.0         0.000000
# AAACATCGAATCCGTCCATTCTAC                3              40.0         0.000000
# ...                                   ...               ...              ...
# TTCACGCAGCTCGGTACATTCCTA                2              34.0         0.263193
# TTCACGCAGTCTGTCAGCTCTACT                3              43.0         0.273973
# TTCACGCATCTTCACAATCCTTAC                2              97.0         0.000000
# TTCACGCATGGAACAAATCTTAGG                0               1.0         0.000000
# TTCACGCATGGCTTCATCTCTAGC                1              12.0         0.000000
#
#                           n_genes_by_counts  total_counts  total_counts_mt  \
# barcode
# AAACATCGAACCGAGAGCAATTCT               1027    870.000005             26.0
# AAACATCGAACGCTTAACATTTGG                135    188.999999              7.0
# AAACATCGAACGTGATACTTCATC                 88    221.999979              8.0
# AAACATCGAACGTGATCATTTGGA                128    233.000034             17.0
# AAACATCGAATCCGTCCATTCTAC                118    196.999978              3.0
# ...                                     ...           ...              ...
# TTCACGCAGCTCGGTACATTCCTA               1697   2532.999780             23.0
# TTCACGCAGTCTGTCAGCTCTACT               1422    729.999832             19.0
# TTCACGCATCTTCACAATCCTTAC                133    237.000014             22.0
# TTCACGCATGGAACAAATCTTAGG                 18     54.000000             20.0
# TTCACGCATGGCTTCATCTCTAGC                 67     98.000040             14.0
#
#                           pct_counts_mt   pool           sample_id    round1  \
# barcode
# AAACATCGAACCGAGAGCAATTCT       2.988506  eRZ58  eRZ58:eRZ58_GEX20A  GCAATTCT
# AAACATCGAACGCTTAACATTTGG       3.703704  eRZ58  eRZ58:eRZ58_GEX20A  ACATTTGG
# AAACATCGAACGTGATACTTCATC       3.603604  eRZ58  eRZ58:eRZ58_GEX20A  ACTTCATC
# AAACATCGAACGTGATCATTTGGA       7.296136  eRZ58  eRZ58:eRZ58_GEX20A  CATTTGGA
# AAACATCGAATCCGTCCATTCTAC       1.522843  eRZ58  eRZ58:eRZ58_GEX20A  CATTCTAC
# ...                                 ...    ...                 ...       ...
# TTCACGCAGCTCGGTACATTCCTA       0.908014  eRZ58  eRZ58:eRZ58_GEX20A  CATTCCTA
# TTCACGCAGTCTGTCAGCTCTACT       2.602740  eRZ58  eRZ58:eRZ58_GEX20A  GCTCTACT
# TTCACGCATCTTCACAATCCTTAC       9.282700  eRZ58  eRZ58:eRZ58_GEX20A  ATCCTTAC
# TTCACGCATGGAACAAATCTTAGG      37.037037  eRZ58  eRZ58:eRZ58_GEX20A  ATCTTAGG
# TTCACGCATGGCTTCATCTCTAGC      14.285708  eRZ58  eRZ58:eRZ58_GEX20A  TCTCTAGC
#
#                           ...   Rep   plate is_cell_Expected_Cells  \
# barcode                   ...
# AAACATCGAACCGAGAGCAATTCT  ...  rep2  plate1                   True
# AAACATCGAACGCTTAACATTTGG  ...  rep2  plate1                   True
# AAACATCGAACGTGATACTTCATC  ...  rep1  plate1                   True
# AAACATCGAACGTGATCATTTGGA  ...  rep2  plate1                   True
# AAACATCGAATCCGTCCATTCTAC  ...  rep1  plate1                   True
# ...                       ...   ...     ...                    ...
# TTCACGCAGCTCGGTACATTCCTA  ...  rep1  plate1                   True
# TTCACGCAGTCTGTCAGCTCTACT  ...  rep1  plate1                   True
# TTCACGCATCTTCACAATCCTTAC  ...  rep1  plate1                   True
# TTCACGCATGGAACAAATCTTAGG  ...  rep2  plate1                   True
# TTCACGCATGGCTTCATCTCTAGC  ...  rep1  plate1                   True
#
#                          is_cell_UMI_Threshold  is_cell_BarcodeRanks_Knee  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                  True                      False
# AAACATCGAACGCTTAACATTTGG                  True                      False
# AAACATCGAACGTGATACTTCATC                  True                      False
# AAACATCGAACGTGATCATTTGGA                  True                      False
# AAACATCGAATCCGTCCATTCTAC                  True                      False
# ...                                        ...                        ...
# TTCACGCAGCTCGGTACATTCCTA                  True                       True
# TTCACGCAGTCTGTCAGCTCTACT                  True                      False
# TTCACGCATCTTCACAATCCTTAC                  True                      False
# TTCACGCATGGAACAAATCTTAGG                  True                      False
# TTCACGCATGGCTTCATCTCTAGC                  True                      False
#
#                           is_cell_BarcodeRanks_Inflection  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                             True
# AAACATCGAACGCTTAACATTTGG                            False
# AAACATCGAACGTGATACTTCATC                            False
# AAACATCGAACGTGATCATTTGGA                            False
# AAACATCGAATCCGTCCATTCTAC                            False
# ...                                                   ...
# TTCACGCAGCTCGGTACATTCCTA                             True
# TTCACGCAGTCTGTCAGCTCTACT                            False
# TTCACGCATCTTCACAATCCTTAC                            False
# TTCACGCATGGAACAAATCTTAGG                            False
# TTCACGCATGGCTTCATCTCTAGC                            False
#
#                           is_cell_Expected_Cells_by_group  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                             True
# AAACATCGAACGCTTAACATTTGG                             True
# AAACATCGAACGTGATACTTCATC                             True
# AAACATCGAACGTGATCATTTGGA                             True
# AAACATCGAATCCGTCCATTCTAC                             True
# ...                                                   ...
# TTCACGCAGCTCGGTACATTCCTA                             True
# TTCACGCAGTCTGTCAGCTCTACT                             True
# TTCACGCATCTTCACAATCCTTAC                             True
# TTCACGCATGGAACAAATCTTAGG                             True
# TTCACGCATGGCTTCATCTCTAGC                             True
#
#                           is_cell_UMI_Threshold_by_group  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                            True
# AAACATCGAACGCTTAACATTTGG                            True
# AAACATCGAACGTGATACTTCATC                            True
# AAACATCGAACGTGATCATTTGGA                            True
# AAACATCGAATCCGTCCATTCTAC                            True
# ...                                                  ...
# TTCACGCAGCTCGGTACATTCCTA                            True
# TTCACGCAGTCTGTCAGCTCTACT                            True
# TTCACGCATCTTCACAATCCTTAC                            True
# TTCACGCATGGAACAAATCTTAGG                            True
# TTCACGCATGGCTTCATCTCTAGC                            True
#
#                           is_cell_BarcodeRanks_Knee_by_group  \
# barcode
# AAACATCGAACCGAGAGCAATTCT                                True
# AAACATCGAACGCTTAACATTTGG                                True
# AAACATCGAACGTGATACTTCATC                                True
# AAACATCGAACGTGATCATTTGGA                                True
# AAACATCGAATCCGTCCATTCTAC                               False
# ...                                                      ...
# TTCACGCAGCTCGGTACATTCCTA                                True
# TTCACGCAGTCTGTCAGCTCTACT                                True
# TTCACGCATCTTCACAATCCTTAC                                True
# TTCACGCATGGAACAAATCTTAGG                               False
# TTCACGCATGGCTTCATCTCTAGC                               False
#
#                           is_cell_BarcodeRanks_Inflection_by_group
# barcode
# AAACATCGAACCGAGAGCAATTCT                                      True
# AAACATCGAACGCTTAACATTTGG                                      True
# AAACATCGAACGTGATACTTCATC                                      True
# AAACATCGAACGTGATCATTTGGA                                      True
# AAACATCGAATCCGTCCATTCTAC                                      True
# ...                                                            ...
# TTCACGCAGCTCGGTACATTCCTA                                      True
# TTCACGCAGTCTGTCAGCTCTACT                                      True
# TTCACGCATCTTCACAATCCTTAC                                      True
# TTCACGCATGGAACAAATCTTAGG                                     False
# TTCACGCATGGCTTCATCTCTAGC                                     False
#
# [4160 rows x 22 columns]

# %% [markdown]
# # perturb anndata

# %%
RESULT_PATH = "/oak/stanford/groups/engreitz/Users/ronghao/Sequencing/20251218_eRZ59_Split-seq_4M_Novaseq/perturb_pipeline/result/results_eRZ58_20A_analysis"
ADATA_PATH = RESULT_PATH+"/counts_filtered/adata.h5ad"
adata = sc.read_h5ad(ADATA_PATH)
obs = adata.obs.copy()
obs
print("AnnData loaded:", adata.shape)
print("\nobs columns preview:\n", list(obs.columns)[:50])
val_cols = ["guides_per_cell", "guide_umi_counts", "n_genes_by_counts", "total_counts"]

df_summary = (
    obs.groupby("biological_sample")
       .agg(
           # cell
           n_cells_per_sample=("biological_sample", "size"),
           n_cells_with_guides=("guides_per_cell", lambda x: int((x > 0).sum())),

           # ---------- GEX ----------
           gex_umis_per_sample=("total_counts", "sum"),
           gex_umis_per_cell_mean=("total_counts", "mean"),
           gex_umis_per_cell_median=("total_counts", "median"),
           genes_per_cell_mean=("n_genes_by_counts", "mean"),
           genes_per_cell_median=("n_genes_by_counts", "median"),

           #  ---------- gRNA ----------
           grna_umis_per_sample=("guide_umi_counts", "sum"),
           grna_umis_per_cell_mean=("guide_umi_counts", "mean"),
           grna_umis_per_cell_median=("guide_umi_counts", "median"),
           grna_detections_per_sample=("guides_per_cell", "sum"),
           grna_per_cell_mean=("guides_per_cell", "mean"),
           grna_per_cell_median=("guides_per_cell", "median"),
           frac_cells_with_guides=("guides_per_cell", lambda x: (x > 0).mean()),
           
           #  ---------- other ----------
           pct_mt_mean=("pct_counts_mt", "mean"),
           pct_mt_median=("pct_counts_mt", "median"),
           pct_ribo_mean=("pct_counts_ribo", "mean"),
           pct_ribo_median=("pct_counts_ribo", "median") 
       )
       .reset_index()
)
df_summary

df_summary.to_csv(RESULT_PATH+"qc_summary.csv", index=False)
# Out:
# AnnData loaded: (4160, 34183)
#
# obs columns preview:
#  ['guides_per_cell', 'guide_umi_counts', 'pct_counts_ribo', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'pool', 'sample_id', 'round1', 'well', 'biological_sample', 'Rep', 'plate']
# /tmp/ipykernel_29931/3940862876.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   obs.groupby("biological_sample")

# %%
df_summary
# Out:
#    biological_sample  n_cells_per_sample  n_cells_with_guides  \
# 0          eRZ53_m1a                  50                   45
# 1          eRZ53_m1b                  33                   29
# 2          eRZ53_m1c                  34                   30
# 3          eRZ53_m1d                  17                   15
# 4          eRZ53_m2a                  35                   29
# ..               ...                 ...                  ...
# 62         eRZ56_m7b                 141                  104
# 63         eRZ58_m1a                  79                   71
# 64         eRZ58_m1b                 109                   86
# 65         eRZ58_m1c                  95                   88
# 66          eRZ58_m2                  81                   73
#
#     gex_umis_per_sample  gex_umis_per_cell_mean  gex_umis_per_cell_median  \
# 0         174337.996762             3486.759935               2816.499889
# 1         155112.002956             4700.363726               3622.999528
# 2         101730.999479             2992.088220               2562.499997
# 3         116012.005832             6824.235637               6216.000125
# 4          58522.999112             1672.085689                772.999920
# ..                  ...                     ...                       ...
# 62         15198.999059              107.794320                 87.999969
# 63        247168.993884             3128.721442               2919.999610
# 64        291259.997942             2672.110073               2300.999752
# 65        193432.993497             2036.136774               1815.999599
# 66         14146.999695              174.654317                139.000008
#
#     genes_per_cell_mean  genes_per_cell_median  grna_umis_per_sample  \
# 0           2241.500000                 1978.5                4702.0
# 1           2197.393939                 1998.0                3742.0
# 2           1802.411765                 1463.5                3729.0
# 3           3398.294118                 3318.0                1600.0
# 4            953.914286                  614.0                7970.0
# ..                  ...                    ...                   ...
# 62            77.886525                   46.0                5235.0
# 63          1951.835443                 1950.0               11037.0
# 64          1704.275229                 1589.0                9326.0
# 65          1384.842105                 1346.0               13095.0
# 66           183.148148                  128.0                9005.0
#
#     grna_umis_per_cell_mean  grna_umis_per_cell_median  \
# 0                 94.040000                       54.5
# 1                113.393939                       79.0
# 2                109.676471                       46.0
# 3                 94.117647                       71.0
# 4                227.714286                      120.0
# ..                      ...                        ...
# 62                37.127660                       16.0
# 63               139.708861                      100.0
# 64                85.559633                       44.0
# 65               137.842105                      103.0
# 66               111.172840                       89.0
#
#     grna_detections_per_sample  grna_per_cell_mean  grna_per_cell_median  \
# 0                          128            2.560000                   2.0
# 1                          103            3.121212                   3.0
# 2                           98            2.882353                   2.0
# 3                           39            2.294118                   2.0
# 4                          213            6.085714                   4.0
# ..                         ...                 ...                   ...
# 62                         210            1.489362                   1.0
# 63                         283            3.582278                   3.0
# 64                         268            2.458716                   2.0
# 65                         323            3.400000                   3.0
# 66                         249            3.074074                   2.0
#
#     frac_cells_with_guides  pct_mt_mean  pct_mt_median  pct_ribo_mean  \
# 0                 0.900000     2.072763       1.815326       0.283104
# 1                 0.878788     2.410668       1.540943       0.207023
# 2                 0.882353     2.554188       2.212892       0.347765
# 3                 0.882353     1.767547       1.801683       0.279034
# 4                 0.828571     2.619789       2.333649       0.234852
# ..                     ...          ...            ...            ...
# 62                0.737589     7.792358       7.258063       0.258979
# 63                0.898734     1.289794       0.902425       0.346226
# 64                0.788991     0.942110       0.713110       0.268942
# 65                0.926316     1.018656       0.655738       0.227578
# 66                0.901235     9.704227       9.011627       0.412956
#
#     pct_ribo_median
# 0          0.282134
# 1          0.199646
# 2          0.322299
# 3          0.271920
# 4          0.217984
# ..              ...
# 62         0.000000
# 63         0.290645
# 64         0.251075
# 65         0.223570
# 66         0.000000
#
# [67 rows x 19 columns]

# %% [markdown]
# # check spilte anndata

# %%
RESULT_PATH = "/oak/stanford/groups/engreitz/Users/ronghao/Sequencing/20251130_eRZ58_Split-seq_test_Nextseq/analysis/eRZ58_GEX60C_analysis/"
ADATA_PATH = RESULT_PATH+"all-sample/DGE_filtered/anndata.h5ad"
adata = sc.read_h5ad(ADATA_PATH)
adata
obs = adata.obs.copy()
obs
# Out:
#              sample             species  gene_count  tscp_count  mread_count
# bc_wells
# 73_07_51  eRZ53_m1a  GRCm39-Cre-mCherry        1026        4057        14291
# 73_11_53  eRZ53_m1a  GRCm39-Cre-mCherry         192         948         3164
# 73_14_03  eRZ53_m1a  GRCm39-Cre-mCherry         876        4258        14892
# 73_15_45  eRZ53_m1a  GRCm39-Cre-mCherry        1230        4513        15976
# 73_15_79  eRZ53_m1a  GRCm39-Cre-mCherry        1219        3965        14863
# ...             ...                 ...         ...         ...          ...
# 72_89_91   eRZ58_m2  GRCm39-Cre-mCherry          25          87          254
# 72_90_36   eRZ58_m2  GRCm39-Cre-mCherry          36         124          373
# 72_91_31   eRZ58_m2  GRCm39-Cre-mCherry          42         112          324
# 72_93_71   eRZ58_m2  GRCm39-Cre-mCherry          47         132          362
# 72_94_03   eRZ58_m2  GRCm39-Cre-mCherry          29         152          395
#
# [4765 rows x 5 columns]
